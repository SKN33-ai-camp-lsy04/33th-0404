# %%
class Phone:
    type = "갤럭시"

    def __init__(self, number, owner):
        self.number = number    # 인스턴스 변수
        self.owner = owner  # 인스턴스 변수
    # init : 매개 변수를 전달받아 인스턴스 속성을 초기화할 수 있다

    number = 83466993   # 클래스 변수
    owner = "이서영"   # 클래스 변수

    def greeting(self):
        print(f'안녕하세요. 나의 핸드폰 기종은 {self.type}이고, 번호는 {self.number}입니다.')
    # self : 필드 및 메서드에 접근하기 위한 "객체"를 의미한다
    # 메소드 호출 시 객체의 주소값이 첫 번째 인자로 넘어온다
    # self가 항상 첫 번째 인자 기능을 한다

p.greeting()

p = Phone(84801848, "김재린")

print(p.number)
print(Phone.number) # 클래스 변수 (모든 인스턴스가 공유하는 속성이다)



# p = Phone("갤럭시", 83466993, "이서영")
# 코드를 보면 생성자의 매개변수 개수와 객체 생성 시 전달한 인자 개수가 맞지 않습니다
# Out:
# 안녕하세요. 나의 핸드폰 기종은 갤럭시이고, 번호는 84801848입니다.
# 84801848
# 83466993

# %%
class Cafe:
    beverage = '커피'     # 인스턴스
    dessert = '티라미수'

    def __init__(self, floor, price):    # 클래스
        self.floor = 3
        self.price = 'expensive'

    def marketing(self):
        return '안녕하세요'

    def information(self):
        return
# Out:
#   Cell In[18], line 12
#     return 'self.beverage + '가 맛있는 셀렉티드 카페입니다''
#                              ^
# SyntaxError: invalid syntax
