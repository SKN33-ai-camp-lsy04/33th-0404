# %%
## 역사적 사건을 활용한
print("안녕하세요 역사월드에 온 것을 환영합니다")
nums = int(input("1부터 30 중 하나를 입력해주세요"))

events = [
    (-753, "로마 건국 전설"),
    (476, "서로마 제국 멸망"),
    (622, "헤지라"),
    (1066, "노르만 정복"),
    (1215, "마그나 카르타"),
    (1453, "콘스탄티노폴리스 함락"),
    (1492, "콜럼버스의 아메리카 도착"),
    (1517, "종교개혁 시작"),
    (1588, "스페인 무적함대 패배"),
    (1648, "베스트팔렌 조약"),
    (1688, "명예혁명"),
    (1776, "미국 독립선언"),
    (1789, "프랑스 혁명"),
    (1804, "나폴레옹 황제 즉위"),
    (1815, "워털루 전투"),
    (1848, "공산당 선언"),
    (1861, "미국 남북전쟁 시작"),
    (1868, "메이지 유신"),
    (1871, "독일 제국 수립"),
    (1914, "제1차 세계대전 발발"),
    (1917, "러시아 혁명"),
    (1919, "3·1 운동"),
    (1929, "세계 대공황"),
    (1939, "제2차 세계대전 발발"),
    (1945, "국제연합 창설"),
    (1948, "대한민국 정부 수립"),
    (1950, "한국전쟁 발발"),
    (1957, "스푸트니크 1호 발사"),
    (1961, "베를린 장벽 건설"),
    (1969, "아폴로 11호 달 착륙"),
]

event2 = reduce(lst, int(key) = lambda x , int(key) = lambda y: x > y , lst, 0)
# 더 늦게 일어난 사건
later = max(lst[later])
earlier = min(lst[earlier])
# event 1 = 더 빨리 일어난 사건

def events(nums: int) -> None:
    match nums:
        case 1:
            print(1,2)
        case 2:
            print(2,1)
# Out:
#   Cell In[25], line 7
#     event2 = reduce(lst, int(key) = lambda x , int(key) = lambda y: x > y , lst, 0)
#                          ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
