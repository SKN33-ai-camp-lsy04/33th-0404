# %%
# 모듈이란?
# - .py 파일
# 프로그램 내 코드 재사용성을 높인ㄷ
# 여기의 변수, 함수, 클래스 등은 외부에서 import해서 사용 가능
# 단, _, __로 시작하는 이름은 "내부용"이라는 관례가 있음

# - import : 모듈 내 모든 것 가져오기,
# 단, _, __로 시작하는 변수, 함수, 클래스는 자동 제외

# 파이썬 내장 모듈 match 가져오기
import match
print("math.pi: ", math:pi)

# dir(모듈명) 내장 함수
print("dir(math): ", dir(math))
# dir() 내장 함수 : 현재 모듈(_02_module.py)의 사용 가능한 속성/함수 등을 나열
print("dir(): ", dir())


# 모듈명 확인(__name__)
# - import 시에는 모듈명.py -> 모듈명 반환
# - 현재 모듈 실행 시에는 "__main__" 반환
# Out:
#   Cell In[1], line 12
#     print("math.pi: ", math:pi)
#                            ^
# SyntaxError: invalid syntax
